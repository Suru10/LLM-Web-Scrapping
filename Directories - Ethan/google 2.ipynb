# %%
import pandas as pd
import googlesearch
import time
#high school, street address, city, state, website url

# %%
df = pd.read_csv('schools_to_be_farmed.csv')

# %%
# ********************************************************** TEST *************************************

# %%
df['query'] = df['school_name'] + ' in ' + df['city'] + ', ' + df['state'] + ' staff administration directory link'

# %%
df['query'].loc[0]
# Out:
# 'cabarrus early college of technology in concord, north carolina staff administration directory link'

# %%
query_list = df['query'].tolist()

# %%
len(query_list)/5
# Out:
# 2154.0

# %%
# ------------------------------------------------- WHOLE DATASET ------------------------------------------------------------------

# %%
query_list[0]
# Out:
# 'cabarrus early college of technology in concord, north carolina staff administration directory link'

# %%
import requests
from requests_ip_rotator import ApiGateway
import os
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import googlesearch
import re

keywords = query_list[2154:2154*2]

def parse(keyword, session):
    search = keyword
    url = 'https://www.google.com/search'
    
    headers = {
	'Accept' : '*/*',
	'Accept-Language': 'en-US,en;q=0.5',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82',
    }
    parameters = {'q': search}
    response = session.get(url, headers = headers, params = parameters)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        search = soup.find(id = 'search')
        first_link = search.find('a')
        print(first_link['href'])
        return first_link['href']
    else:
        print('Error')
        return 'Error'


AWS_ACCESS_KEY_ID = 'AKIAUYSFDI55SAGHWSXR'
AWS_SECRET_ACCESS_KEY = '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'

gateway = ApiGateway("https://www.google.com", access_key_id=AWS_ACCESS_KEY_ID,
                         access_key_secret=AWS_SECRET_ACCESS_KEY)
gateway.start()

session = requests.Session()
session.mount("https://www.google.com", gateway)
lst = []
count = 0
for keyword in keywords:
    lst.append(parse(keyword, session))
    count += 1
    print(count)
    
gateway.shutdown()
# Out:
# Starting API gateways in 10 regions.
# Using 10 endpoints with name 'https://www.google.com - IP Rotate API' (10 new).
# https://www.pennmanor.net/directory/
# 1
# https://highschool.plsd.k12.pa.us/apps/staff/
# 2
# https://highschool.prc.k12.ms.us/administration
# 3
# https://highschool.ptschools.org/staff_directory
# 4
# https://www.tylerisd.org/o/legacy/staff
# 5
# https://highschool.rsu57.org/o/mhs/staff
# 6
# https://hs-sau56.ss20.sharpschool.com/resources/staff
# 7
# https://shpsmohr.ss4.sharpschool.com/staff_
# 8
# https://highschool.snyderisd.net/o/shs/staff
# 9
# https://highschool.stcmo.org/staff-directory
# 10
# https://highschool.williamsburg.k12.ia.us/building_information/staff_directory
# 11
# https://hillcrest.bhsd228.com/
# 12
# https://hilltopchristianschool.com/staff/
# 13
# https://www.cde.ca.gov/schooldirectory/details?cdscode=30736433032919
# 14
# https://hillwood.mnps.org/our_school/directory
# 15
# https://hinghamschools.org/hingham-high-school/teachers/
# 16
# https://aurorak12.org/contact-us/directories/
# 17
# https://hitchcockhighschool.hitchcockisd.org/about-us/faculty-staff
# 18
# https://www.hardee.k12.fl.us/
# 19
# https://hlcsk12.net/our-district/staff-directory/
# 20
# https://hlh.desotocountyschools.org/staff
# 21
# https://hmhs.hopkintonschools.org/en-US/staff
# 22
# https://hmltrojans.org/m/staff/
# 23
# https://nccvt-hodgson.edlioschool.com/apps/staff/
# 24
# https://nccvt-hodgson.edlioschool.com/apps/staff/
# 25
# https://hoggard.nhcs.net/faculty-staff
# 26
# https://hohs.hcpss.org/school-staff
# 27
# https://www.cde.ca.gov/schooldirectory/details?cdscode=57726786060396
# 28
# https://home.gatewaycharterhigh.org/apps/staff/
# 29
# https://home.isd1.org/staff-directory.html
# 30
# https://www.poloschools.net/staff
# 31
# https://hoover.dmschools.org/staff-directory/
# 32
# https://hope.auhsd.us/Hope/Department/12100-AdministrativeTeam
# 33
# https://hopkinsvillehigh.christian.kyschools.us/staff
# 34
# https://horizonchristianschool.org/faculty-staff-board/
# 35
# https://horizonindy.org/school/about/staff/
# 36
# http://horizonte.slcschools.org/our-school/administration-staff-directory
# 37
# https://ny50000160.schoolwires.net/Page/1044
# 38
# https://www.houston.k12.mo.us/staff
# 39
# https://howard.hcde.org/directory
# 40
# https://howard.nccvt.k12.de.us/apps/pages/index.jsp?uREC_ID=1826668&type=d&pREC_ID=2180443
# 41
# https://howardfullerca.org/parents-2/staff-directory/
# 42
# https://www.schools.nyc.gov/schools/M708
# 43
# https://hphs.topekapublicschools.net/staff
# 44
# https://hpiam.marquezhs.net/apps/staff/
# 45
# https://hpiam.marquezhs.net/apps/staff/
# 46
# https://hs.s-tama.k12.ia.us/en-US/staff
# 47
# https://hs.amelia.k12.va.us/a_c_h_s_staff_directory
# 48
# https://hs.bgisd.org/apps/staff/
# 49
# https://www.bhmsd.org/staff
# 50
# https://www.blufftonschools.org/staff
# 51
# https://hs.bsd29j.com/apps/staff/
# 52
# https://hs.btownccs.k12.in.us/students-parents/faculty-directory
# 53
# https://hs.caldwellschools.net/apps/staff/
# 54
# https://hs.californiak12.org/apps/staff/
# 55
# https://www.calsd.org/apps/staff/
# 56
# https://hs.capitantigers.org/Our_Staff
# 57
# https://www.cedarvilleschools.org/staff
# 58
# https://www.centralisd.com/apps/staff/
# 59
# https://hs.chichestersd.org/m/pages/index.jsp?uREC_ID=300653&type=d
# 60
# https://hs.chisddevils.com/26010_1
# 61
# https://cisdtx.net/308571_2
# 62
# https://hs.clinton.k12.ma.us/apps/staff/
# 63
# https://www.crschools.org/parents/staff_directory
# 64
# https://hs.ctasd.org/Faculty-and-Staff
# 65
# https://www.cumberlandacademy.com/apps/staff/
# 66
# https://hs.curwensville.org/en/staff
# 67
# https://hs.cuyhts.org/apps/pages/index.jsp?uREC_ID=2324406&type=d&pREC_ID=2213861&tota11y=true
# 68
# https://hs.cvsd.net/about-cvhs/directory
# 69
# https://hs.delphi.k12.in.us/staff_directory
# 70
# http://www.dexterdemons.org/staff_directory
# 71
# https://hs.dinwiddie.k12.va.us/staff/
# 72
# https://hs.dlschools.net/about-us/staff-directory
# 73
# https://hs.dnhcsd.org/en-US/staff
# 74
# https://hs.doverschools.org/staff?page_no=1
# 75
# https://hs.dryden.k12.ny.us/staff_directory
# 76
# https://hs.durand.k12.mi.us/apps/staff/
# 77
# https://hs.eastnoble.net/staff
# 78
# https://hs.ehornets.org/apps/staff/
# 79
# https://hs.elkcityschools.com/195088_2?personID=163597
# 80
# https://hs.fisd.us/apps/staff/
# 81
# https://hs.forsythpanthers.org/staff_directory
# 82
# https://hs.forsythpanthers.org/staff_directory
# 83
# https://hs.foukepanthers.org/113850_2
# 84
# https://hs.fountainhillsschools.org/m/staff/
# 85
# https://hs.franklintowne.org/staff
# 86
# https://www.frionaisd.com/65881_2
# 87
# http://www.gnasd.com/staff_directory
# 88
# https://hs.godwinschools.org/apps/staff/
# 89
# https://www.goliadisd.org/579724_3
# 90
# https://hs.grantps.net/Staff
# 91
# https://www.greeneview.org/staff
# 92
# https://hs.groesbeckisd.net/53917_2
# 93
# https://south.gsastl.org/apps/staff/
# 94
# https://hs.gsd.wednet.edu/apps/staff/
# 95
# https://www.hannasd.org/our-district/staff-directory
# 96
# https://harpercreek.ss7.sharpschool.com/staff_directory
# 97
# https://hs.hassk12.org/apps/staff/
# 98
# https://hs.hatchschools.net/staff
# 99
# https://cdnsm5-ss19.sharpschool.com/UserFiles/Servers/Server_136831/File/Faculty%20&%20Staff%20Lists/Staff%20Directory%209-19-19.pdf
# 100
# https://www.hoosacvalley.org/staff-resources
# 101
# https://hs.hpisd.org/apps/staff/
# 102
# https://sd.hancock.k12.mo.us/
# 103
# https://hs.hpsmi.org/apps/staff/
# 104
# https://hs.humboldtunified.com/m/staff/
# 105
# https://hs.jcschools.com/staff
# 106
# https://hs.jeannetteschooldistrict.org/apps/staff/
# 107
# https://www.jeff-davis.k12.ga.us/apps/staff/
# 108
# https://www.jerichoschools.org/contact-us/administrative-directory
# 109
# https://hs.johnson.k12.ga.us/about-us/staff-directory
# 110
# https://hs.knox.k12.in.us/staff_directory
# 111
# https://hs.l-spioneers.org/school-information/staff-directory
# 112
# https://ms.lackawannaschools.org/o/lhs/staff
# 113
# http://www.laferiaisd.org/our_district/lfisd_district_and_campus_directory
# 114
# https://hs.lamarschools.org/apps/staff/
# 115
# https://www.lamarwarriors.org/177732_2
# 116
# https://hs.leisd.net/12415_1
# 117
# https://hs.lfalls.k12.mn.us/about/staff-directory
# 118
# https://hs.lg.k12.ok.us/112195_2
# 119
# https://hs.llanoisd.org/apps/staff/
# 120
# https://www.logrog.net/453963_3
# 121
# https://hs.lorenaisd.net/apps/staff/
# 122
# https://www.luling.txed.net/staff
# 123
# https://hs.marsingschools.org/o/mhs/page/staff
# 124
# https://hs.maysville.k12.mo.us/staff_directory
# 125
# https://hs.midwestcentral.org/staff
# 126
# https://hs.millburyschools.org/about-mmjshs/e-mail-directory
# 127
# https://hs.mlschools.org/our_school/about_mlhs_contact_info/staff_directory
# 128
# https://hs.mmsaonline.org/apps/staff/
# 129
# https://www.mobridge-pollock.k12.sd.us/staff?page_no=4
# 130
# https://hs.moodyisd.org/apps/staff/
# 131
# https://hs.mtpcsd.org/apps/pages/index.jsp?uREC_ID=1381129&type=d&pREC_ID=1563026
# 132
# https://www.mtvernonisd.net/345488_2
# 133
# https://hs.nbbroncos.net/about-nbhs/directory
# 134
# https://hs.nbschools.net/277116_2?offset=12&ppl=2
# 135
# https://hs.nchcityschools.org/apps/staff/
# 136
# https://www.ncsd.k12.pa.us/
# 137
# https://hs.neptuneschools.org/m/staff/
# 138
# https://hs.norwoodschools.org/about-us/staff-directory
# 139
# https://ofsd.cc/en/staff
# 140
# https://hs.parkrose.k12.or.us/staff?query=parkrose%20high
# 141
# https://hs.pcmschools.org/apps/staff/
# 142
# https://hs.pequannock.org/about/directory
# 143
# https://www.phillytornadoes.com/apps/staff/
# 144
# https://hs.pvre7.org/en/staff
# 145
# https://ppswi.us/www.platteville.k12.wi.us/schools/high/academics/hs_StaffDirectory.cfm%3Flastname=&firstname=&groupid=&positiontitle=&maxrows=50&dosearch=1&sortby=group&startrow=51.html
# 146
# https://hs.poplarbluffschools.net/about_our_school/staff_directory
# 147
# https://hs.pspcisd.net/20599_2
# 148
# https://hs.resc.k12.in.us/apps/staff/
# 149
# https://www.rivervalleysd.org/
# 150
# https://hs.rockdaleisd.net/our-staff
# 151
# https://hs.rpsd.org/
# 152
# https://www.rvk12.org/our-district/staff-directory
# 153
# https://hs.saisd.us/apps/staff/
# 154
# https://www.sbepschools.org/contact_us/staff_directory
# 155
# https://hs.sdsm.k12.wi.us/staff_directory
# 156
# https://hs.shhawks.net/en-US/staff
# 157
# https://hs.showlow.education/staff/?page_no=4
# 158
# https://hs.shrsd.org/staff_directory
# 159
# https://hs.slvusd.org/apps/pages/index.jsp?uREC_ID=1104252&type=d&pREC_ID=1400696
# 160
# https://hs.smethportschools.com/Our-Staff
# 161
# https://hs.southbridgepublic.org/apps/pages/index.jsp?uREC_ID=2062241&type=d
# 162
# https://hs.ssdvt.org/apps/staff/
# 163
# https://hs.swartzcreek.org/
# 164
# https://hs.swsd.k12.pa.us/staff_directory/staff_directory
# 165
# https://hs.taftisd.net/apps/staff/
# 166
# https://hs.timpsonisd.com/en-US/staff
# 167
# https://hs.tonasket.wednet.edu/contact_us/staff_directory
# 168
# https://hs.ulusd.org/m/staff/
# 169
# https://edu.fcps.org/uhs/staff
# 170
# https://hs.usd470.com/14371_1
# 171
# https://hs.wc314.org/apps/staff/
# 172
# https://hs.wcs.k12.oh.us/district/directory.jsp
# 173
# https://www.westernheights.k12.ok.us/staff
# 174
# https://hs.westisd.net/apps/staff/
# 175
# https://hs.westville.k12.in.us/faculty/staff_directory
# 176
# https://westwood.roundrockisd.org/directory/
# 177
# https://hs.whitesboroisd.org/m/staff/
# 178
# https://hs.wl.k12.in.us/contact/faculty-directory
# 179
# https://hs.woccisd.net/apps/staff/
# 180
# https://www.wpsd.net/district/directory
# 181
# https://hs.wrv.k12.in.us/about_us/staff
# 182
# https://hs.wvsd208.org/contact
# 183
# https://hs.ycsd.k12.or.us/staff_directory
# 184
# https://hs544x.echalksites.com/directory/faculty
# 185
# https://hsadallas.harmonytx.org/staff/staff-quicklinks
# 186
# https://hsahouston.harmonytx.org/staff/staff-quicklinks
# 187
# https://hsapflugerville.harmonytx.org/staff/staff-quicklinks
# 188
# https://hsasa.harmonytx.org/staff/staff-quicklinks
# 189
# https://hsbc.burlington-nj.net/apps/staff/
# 190
# https://profiles.doe.mass.edu/profiles/general.aspx?topNavId=1&orgcode=02810510&orgtypecode=6&leftNavId=122&
# 191
# https://hsdhouston.harmonytx.org/staff/staff-quicklinks
# 192
# https://hseaustin.harmonytx.org/staff/staff-quicklinks
# 193
# https://hsedallas.harmonytx.org/staff/staff-quicklinks
# 194
# https://hselaredo.harmonytx.org/staff/staff-quicklinks
# 195
# https://hses.philasd.org/staff/
# 196
# https://www.schools.nyc.gov/schools/M399
# 197
# https://www.schools.nyc.gov/schools/M296
# 198
# https://hshp.hcisd.org/apps/staff/
# 199
# https://hshs.jcboe.org/apps/staff/
# 200
# https://hsibrownsville.harmonytx.org/staff/staff-quicklinks
# 201
# https://hsidallas.harmonytx.org/staff/staff-quicklinks
# 202
# https://hsifortworth.harmonytx.org/staff
# 203
# https://hsikaty.harmonytx.org/staff/staff-quicklinks
# 204
# https://hsingenuity.harmonytx.org/staff/staff-quicklinks
# 205
# https://hsiwaco.harmonytx.org/staff/staff-quicklinks
# 206
# https://hsla-lausd-ca.schoolloop.com/pf4/cms2/view_page?d=x&group_id=1537515970438&vdid=7i4b2kgzv2cv
# 207
# https://www.isd2184.net/about_lps/administration
# 208
# https://hsms.pasd.org/staff_directory
# 209
# https://hspaustin.harmonytx.org/staff/staff-quicklinks
# 210
# https://www.schools.nyc.gov/schools/X543
# 211
# https://humphreyscountyhigh.masd.k12.ms.us/staff
# 212
# https://hunterslane.mnps.org/our_school/directory
# 213
# https://hhs.huntingtonisd.com/apps/staff/
# 214
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331934157
# 215
# https://huntland.fcstn.net/facultydirectory
# 216
# https://huntsd.org/staff-list-2019-2020/
# 217
# https://hvam.k12.com/about-our-school/meet-our-team.html
# 218
# https://hvh.ccboe.org/o/hvh/staff
# 219
# https://hvs.highlands.k12.fl.us/contact-us/staff-and-support
# 220
# https://hydeparkcps.org/apps/staff/
# 221
# https://ibh.leeschools.net/our_school/administration
# 222
# https://icademyglobal.org/contact/
# 223
# https://icbschool.org/about-us/faculty-directory/
# 224
# https://ich.leeschools.net/about/staff_directory_2
# 225
# https://www.indiancreekschools.org/apps/staff/
# 226
# https://ics-charter.org/staff-directory/
# 227
# https://idea.guhsd.net/Staff-Directory/
# 228
# https://idea.tacomaschools.org/contact
# 229
# https://ideapublicschools.org/our-schools/idea-alamo/
# 230
# https://ideapublicschools.org/our-schools/idea-carver/
# 231
# https://ideapublicschools.org/our-schools/idea-brownsville/
# 232
# https://ideapublicschools.org/our-schools/idea-donna/
# 233
# https://ideapublicschools.org/our-schools/idea-edinburg/
# 234
# https://ideapublicschools.org/our-schools/idea-frontier/
# 235
# https://ideapublicschools.org/our-schools/idea-mcallen/
# 236
# https://ideapublicschools.org/our-schools/idea-mission/
# 237
# https://www.ideamonterreypark.com/staff-directory.html
# 238
# https://ideapublicschools.org/our-schools/idea-montopolis/
# 239
# https://ideapublicschools.org/our-schools/idea-pharr/
# 240
# https://ideapublicschools.org/our-schools/idea-pharr/
# 241
# https://ideapublicschools.org/our-schools/idea-quest/
# 242
# https://ideapublicschools.org/our-schools/idea-san-benito/
# 243
# https://ideapublicschools.org/our-schools/idea-san-juan/
# 244
# https://ideapublicschools.org/our-schools/idea-south-flores/
# 245
# https://ideapublicschools.org/our-schools/idea-walzem/
# 246
# https://ideapublicschools.org/our-schools/idea-weslaco/
# 247
# https://idva.k12.com/
# 248
# https://www.linkedin.com/school/ghazalyhigh/
# 249
# https://iforwardwisconsin.com/staff
# 250
# https://ihms.tangischools.org/directory
# 251
# https://www.paterson.k12.nj.us/
# 252
# https://ihs.inglewoodusd.com/apps/staff/
# 253
# https://ihs.jcboe.org/apps/staff/
# 254
# https://ihs.morrow.k12.or.us/o/ihs/staff
# 255
# https://ihs.rale.k12.wv.us/o/inh/staff
# 256
# https://www.schools.nyc.gov/schools/K524
# 257
# https://ii.jcboe.org/apps/staff/
# 258
# https://ilc.edu/about/faculty/
# 259
# https://ilearnschools.org/bergen-arts-science-charter-school/
# 260
# https://homeroom5.doe.state.nj.us/directory/charter.php?grade=12
# 261
# https://ilearnschools.org/passaic-arts-science-charter-school/
# 262
# https://ilearnschools.org/paterson-arts-science-charter-school/
# 263
# https://www.imaginenorthtexas.org/m/pages/index.jsp?uREC_ID=376878&type=d&termREC_ID=&pREC_ID=SPOT-9315
# 264
# https://in01000714.schoolwires.net/domain/332
# 265
# https://in02200674.schoolwires.net/domain/8455
# 266
# https://in02200674.schoolwires.net/domain/6933
# 267
# https://independence.rrps.net/
# 268
# https://indianapolismet.org/directory/
# 269
# https://www.cde.ca.gov/schooldirectory/details?cdscode=36678760125450
# 270
# https://inda.k12.com/
# 271
# https://www.cde.ca.gov/SchoolDirectory/details?cdscode=19644690139535
# 272
# https://infotechhs.net/
# 273
# http://www.unioncountysd.schoolinsites.com/?DivisionID=17413&DepartmentID=18820&SubDepartmentID=9093&ToggleSideNav=ShowAll
# 274
# https://www.cde.ca.gov/schooldirectory/details?cdscode=30103060134841
# 275
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37679830134890
# 276
# https://www.schools.nyc.gov/schools/X268
# 277
# https://insightaz.k12.com/about-our-school/meet-our-team.html
# 278
# https://www.cde.ca.gov/schooldirectory/details?cdscode=39686270133116
# 279
# https://insightks.k12.com/about-our-school/meet-our-team.html
# 280
# https://insightmi.k12.com/about-our-school/meet-our-administrators.html
# 281
# https://insightor-ph.k12.com/about-our-school/meet-our-administrators.html
# 282
# https://insightpa.k12.com/about-our-school/meet-our-team.html
# 283
# https://insightwa.k12.com/
# 284
# https://hs.winfield.k12.mo.us/189991_2
# 285
# https://interagency.seattleschools.org/staff/page/3/
# 286
# https://mhs.mansfieldschools.com/about/staff_directory
# 287
# https://intrinsicschools.org/team/
# 288
# https://iprepacademy.com/staff-directory/
# 289
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19734520120600
# 290
# https://iqacademymn.k12.com/about-our-school/meet-our-team.html
# 291
# https://irvinehigh.iusd.org/directory-grid/all
# 292
# https://irving.greatheartsamerica.org/upperschoolfaculty/
# 293
# https://www.cde.ca.gov/schooldirectory/details?cdscode=01611760134270
# 294
# https://irvington.k12.nj.us/district/staff-directory/
# 295
# https://isaacbear.nhcs.net/faculty-staff
# 296
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647330123166
# 297
# https://www.zoominfo.com/pic/ischool-virtual-academy/476542481
# 298
# https://www.ischs.net/apps/staff/
# 299
# https://www.isd181.org/departments/business_services/staff_directory
# 300
# https://islamicschoolofirving.org/faculty-staff/
# 301
# https://islandparkhs.com/apps/staff/
# 302
# https://islaschool.com/directory/
# 303
# https://islc-lausd-ca.schoolloop.com/hsstaff
# 304
# https://isucceedvhs.net/why-isucceed/faculty-staff/
# 305
# https://itech.vansd.org/directory-and-staff/
# 306
# https://itms.islandtrees.org/m/staff/
# 307
# https://www.ivcschools.com/district-information/administration
# 308
# https://ivsec.apluscharterschools.org/306063_2
# 309
# https://iwacademy.com/faculty-and-staff/
# 310
# https://jameslick.esuhsd.org/Staff-Directory/
# 311
# https://jbhs.rcstn.net/school_directory
# 312
# https://jcechs.lajoyaisd.com/o/jcechs/staff
# 313
# https://jcfa.co/
# 314
# https://jchs.jacksoncoschools.com/apps/staff/
# 315
# https://jchs.jcsc.org/accnt_377504/site_378275/Documents/JCHS-Staff-Emails.pdf
# 316
# https://www.johnsoncntyschs.tn.schools.bz/1/Staff
# 317
# https://www.jeffcopublicschools.org/
# 318
# https://jdhs.juneauschools.org/en-US/staff
# 319
# https://www.elizabethschooldistrict.org/domain/128
# 320
# https://www.epsnj.org/Page/120
# 321
# https://jedivirtual.org/
# 322
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331934371
# 323
# https://jeffersonacademysecondary.jeffcopublicschools.org/staff
# 324
# https://jeffersonjrsr.jeffcopublicschools.org/staff
# 325
# https://www.cde.ca.gov/schooldirectory/details?cdscode=10621661030287
# 326
# https://jfhs.jcboe.org/apps/staff/
# 327
# https://jfk.dpsk12.org/about/meet-our-staff/
# 328
# https://jfkennedy.eisd.net/
# 329
# https://jfwh.gcs.k12.nc.us/staff-directory
# 330
# https://jhcisdhhs.ss19.sharpschool.com/about_us/faculty
# 331
# https://www.cde.ca.gov/SchoolDirectory/details?cdscode=07773540132233
# 332
# https://www.d214.org/domain/470
# 333
# https://jhhs.jpsb.us/315763_2
# 334
# https://jhhs.tcsd.org/faculty-staff-directory13
# 335
# https://jhs.baugo.org/administration
# 336
# https://jhs.chiltonboe.com/staff
# 337
# https://www.gjcs.k12.in.us/quicklinks/staff-directory
# 338
# https://jhs.gjsd.net/apps/staff/
# 339
# https://jhs.iberiaschools.org/29421_1
# 340
# https://www.jarrellisd.org/site/Default.aspx?PageType=1&SiteID=4&ChannelID=15&DirectoryType=6
# 341
# https://www.jasper.k12.al.us/faculty-information
# 342
# https://www.jasperisd.net/357345_2
# 343
# https://jhs.jeffersonisd.org/269152_2
# 344
# https://jhs.jisd.org/apps/staff
# 345
# https://jhs.johnstonschools.org/apps/staff/
# 346
# https://jhs.jonesvilleschools.org/staff
# 347
# https://jhs.jsd117.org/school_information/staff_directory
# 348
# https://jhs.lwsd.org/about-us/staff-directory
# 349
# https://jjhs.klschools.org/directory/faculty
# 350
# https://jkohighschool.org/staff-directory
# 351
# https://www.johnmarshallhs.org/apps/staff/
# 352
# https://jmhs.fxbgschools.us/about/staff
# 353
# https://boe.monroe.k12.wv.us/o/jms/staff
# 354
# https://jmhs.rochesterschools.org/about-us/staff-directory
# 355
# https://jmhs.rvaschools.net/about-us/staff-directory
# 356
# https://jmsa.ucboe.us/apps/staff/
# 357
# https://johnfkennedy.kippneworleans.org/apps/staff/
# 358
# https://johnsburg12.cyberschool.com/JHS/Staff
# 359
# https://joneshs.ocps.net/faculty___staff/administration
# 360
# https://josemartimast.net/staff-directory/
# 361
# https://jphschoice.org/about-us/staff/
# 362
# https://jrhs.bcps.k12.va.us/staff_directory
# 363
# https://www.toutlesd.org/apps/staff/
# 364
# https://granvillecsd.ss12.sharpschool.com/cms/One.aspx?portalId=12172775&pageId=12424232
# 365
# https://www.madrid.k12.ia.us/apps/staff/
# 366
# https://www.madrid.k12.ia.us/apps/staff/
# 367
# https://jshs.ascisd.net/apps/staff/
# 368
# https://www.canastotacsd.org/district/staff-directory
# 369
# https://jshs.elklakeschool.org/directory
# 370
# https://jshs.jonesnc.net/o/jshs/staff
# 371
# https://www.soduscsd.org/apps/staff/
# 372
# https://jshs.tangischools.org/directory
# 373
# https://jurupausd.org/schools/PatriotHighSchool/Pages/Directory.aspx
# 374
# https://jurupausd.org/schools/JurupaValleyHighSchool/Pages/Directory.aspx
# 375
# https://jurupausd.org/schools/NuevaVistaContinuationHigh/Pages/Directory.aspx
# 376
# https://jwmhs.pasco.k12.fl.us/how-to-contact-your-teacher/
# 377
# https://kauhale.kanuokaaina.org/kumu-and-staff/
# 378
# https://katywestparkhs.iltexas.org/staff-directory
# 379
# https://kcapa.philasd.org/faculty-staff/
# 380
# https://kcchristianschool.org/our-staff/
# 381
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37683380107094
# 382
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37683380107102
# 383
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37683380107086
# 384
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37683380107102
# 385
# https://kellamhs.vbschools.com/school/staff
# 386
# https://crschools.us/schools/high-schools/
# 387
# https://www.cde.ca.gov/schooldirectory/details?cdscode=01611760134452
# 388
# https://kennedyacademy.org/m/staff/
# 389
# https://kennedycatholic.org/contact-us/connect-with-kennedy-personnel/
# 390
# https://kennewick.ksd.org/connect/contact-us
# 391
# https://kensingtonhs.philasd.org/faculty-staff/
# 392
# https://kenston.org/academics/faculty-staff/
# 393
# https://kenwoodhigh.cmcss.net/directory/
# 394
# https://kernvalley.kernhigh.org/apps/staff/
# 395
# https://www.zoominfo.com/pic/keystone-prep-high-school/350608085
# 396
# https://kghs.kgcs.k12.va.us/staff
# 397
# https://khcs.org/directory/
# 398
# https://khs.hampton.k12.va.us/home/contact-us
# 399
# https://khs.kanek12.org/khs-directory/
# 400
# https://khs.kearneypublicschools.org/apps/staff/
# 401
# https://khs.keeneschoolsnh.org/apps/staff/
# 402
# https://khs.kelloggschools.org/general-info/staff-directory
# 403
# https://khs.kisd.org/
# 404
# https://khs.knappa.k12.or.us/schoolstaff
# 405
# https://khs.kokomoschools.com/staff/school_staff
# 406
# https://khs.kountzeisd.org/356897_2
# 407
# https://khs.krumisd.net/
# 408
# https://khs.kearneypublicschools.org/apps/staff/
# 409
# https://khs.kusd.org/about/staff-directory
# 410
# https://www.cde.ca.gov/schooldirectory/details?cdscode=34765053430634
# 411
# https://khs.vpsb.net/o/khs/staff
# 412
# https://khsa.philasd.org/staff-members/
# 413
# https://kilmercenter.fcps.edu/staff-directory
# 414
# https://www.cde.ca.gov/schooldirectory/details?cdscode=39754990119040
# 415
# https://kimme.vacavilleusd.org/
# 416
# https://king.ccisd.us/directory
# 417
# https://kingchavez.org/high-school/
# 418
# https://kingfisher.k12.ok.us/district-staff/
# 419
# https://kingsschools.org/about/faculty-staff/
# 420
# https://kingston.k12.mo.us/district/directory-district-staff/
# 421
# https://www.cde.ca.gov/schooldirectory/details?cdscode=16639580136556
# 422
# https://kippcolorado.org/our-schools/kipp-denver-collegiate-high-school/
# 423
# https://profiles.doe.mass.edu/profiles/general.aspx?topNavId=1&orgcode=04290000&orgtypecode=5&leftNavId=122&
# 424
# https://www.linkedin.com/school/kipp-atlanta-collegiate/
# 425
# https://portal.tssaa.org/common/directory/?id=273
# 426
# https://kippnc.org/staff-directory/
# 427
# https://www.schools.nyc.gov/schools/X704
# 428
# https://www.schools.nyc.gov/schools/M336
# 429
# https://www.philasd.org/charterschools/directory/kipp-dubois-charter-school/
# 430
# https://kipptexas.org/school-directory/
# 431
# https://kipptexas.org/school-directory/
# 432
# https://kipptexas.org/school-directory/
# 433
# https://kipptexas.org/school-directory/
# 434
# https://kipptexas.org/school-directory/
# 435
# https://kipptexas.org/school-directory/
# 436
# https://kipptexas.org/school-directory/
# 437
# https://kitcarson.scusd.edu/staff
# 438
# http://kittson.k12.mn.us/staff-directory.html
# 439
# https://koinoniaacademy.org/staff
# 440
# https://konoctiusd.org/LLHS/Staff/
# 441
# https://kpbsd.org/schools/homer-high/staff/
# 442
# https://kpbsd.org/schools/kenai-central/staff/
# 443
# https://kpbsd.org/schools/soldotna-high/staff/
# 444
# https://kphermosa.org/faculty-and-staff/
# 445
# https://kps-ok.schoolloop.com/teachercontact
# 446
# https://krhs.nelsd.org/staff-directory
# 447
# https://www.ksd403.org/staff
# 448
# https://kunsmiller.dpsk12.org/faculty-staff/
# 449
# https://www.kvusd.org/KHS/Staff/
# 450
# https://kwhs.kwcps.k12.va.us/about_us/staff_directory
# 451
# https://kwoods.org/faculty
# 452
# https://la.pathwaysineducation.org/
# 453
# https://labrae.school/staff-directory
# 454
# https://lacjhs.org/apps/staff/
# 455
# https://lacordaireacademy.com/faculty-and-staff/
# 456
# https://lafayette.sjsd.k12.mo.us/
# 457
# https://lahs.mvla.net/staff-directory/
# 458
# https://lahs.laschools.net/about/directory
# 459
# https://www.lasd.us/staff
# 460
# https://lahs.losal.org/our-school/lahs-staff-directory
# 461
# https://lahs.msad52.org/en/staff
# 462
# https://lajollahigh.sandiegounified.org/academics/staff_list
# 463
# https://lakelindenschools.org/high-faculty-staff.php
# 464
# https://lakenonahs.ocps.net/staff_directory
# 465
# https://lakeregionhigh.polkschoolsfl.com/staff/
# 466
# https://lakerschools.org/lakers-staff/
# 467
# https://lakes.cloverpark.k12.wa.us/staff_directory
# 468
# https://lakeshorehigh.stpsb.org/our-school/faculty-and-staff
# 469
# https://lakeview.saisd.org/connect/directory
# 470
# https://lam.sd83.org/our_school/faculty_email
# 471
# https://landmark.nebo.edu/faculty
# 472
# https://edisonhs.fcps.edu/staff-directory
# 473
# https://langleyhs.fcps.edu/staff-directory
# 474
# https://lanier.bcss.schoolinsites.com/schoolstaff
# 475
# https://lankenau.philasd.org/our-staff/
# 476
# https://lascuoladitalia.org/who-we-are/leadership/
# 477
# https://www.cde.ca.gov/schooldirectory/details?cdscode=43695750129940
# 478
# https://lavca.k12.com/
# 479
# https://lavelleprep.org/our-team-upper/
# 480
# https://lawrencehighschool.lawrence.org/staff?page_no=4
# 481
# https://lbhs.bcps.k12.va.us/staff_directory
# 482
# https://lbhs.lbsdk12.com/en-US/staff
# 483
# https://www.austinisd.org/schools/lbj/directory
# 484
# https://millikan.lbschools.net/academics/staff
# 485
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647256015531
# 486
# https://poly.lbschools.net/our-school/staff
# 487
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647251996503
# 488
# https://lca.collegiateacademies.org/
# 489
# https://lca.edu/about/
# 490
# https://lcca.hallco.org/
# 491
# https://www.leominster-ma.gov/Directory.aspx
# 492
# https://www.zoominfo.com/pic/leflore-county-high-school/46433875
# 493
# https://www.lawcosd.org/apps/pages/index.jsp?uREC_ID=1758299&type=d&pREC_ID=1967030
# 494
# https://lchs.lcfalcons.net/en-US/staff
# 495
# https://lchs.lcps.k12.va.us/staff
# 496
# https://lchs.lcsb.org/staff
# 497
# https://lchs.lewisk12.org/35517_1
# 498
# https://lchs.lincolncountyschools.org/staff
# 499
# https://lcmhs.lcmcisd.org/9648_1
# 500
# https://lcsd.k12.ms.us/apps/pages/index.jsp?uREC_ID=1568909&type=d&pREC_ID=1748062
# 501
# https://lcsd.k12.ms.us/apps/staff/
# 502
# https://lcsd.k12.ms.us/apps/staff/
# 503
# https://pvhspanthers.com/faculty-staff/
# 504
# https://lcvs.lake.k12.fl.us/our-school/contact-us
# 505
# https://leadingedgeacademy.com/gilbert-early-college/gec-staff/
# 506
# https://leadpublicschools.org/team/
# 507
# https://leadpublicschools.org/team/
# 508
# https://www.connectionsacademy.com/tennessee-online-school/overview/staff/
# 509
# https://leelchs.leeschooldistrictsc.org/apps/staff/
# 510
# https://lefloremcpssal.schoolinsites.com/staff
# 511
# https://www.legacyhigh.net/apps/staff/
# 512
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331931633
# 513
# https://leigh.cuhsd.org/apps/staff/
# 514
# https://leland.sjusd.org/who-we-are/staff-directory/
# 515
# https://leroygreene.com/staff/
# 516
# https://lewis.region10ct.org/school-information/school-leadership
# 517
# https://lewishs.fcps.edu/staff-directory
# 518
# https://portal.tssaa.org/common/directory/?id=291
# 519
# https://www.cde.ca.gov/schooldirectory/details?cdscode=34673143430352
# 520
# https://lfo.catoosa.k12.ga.us/staff_directory
# 521
# https://lhhs.lhusd.org/ourstaff
# 522
# https://lhs.aacs.net/Staff-Directory/
# 523
# https://lhs.alpineschools.org/faculty-staff/
# 524
# https://lhs.carrollk12.org/about/staff-directory
# 525
# https://lhs.dalecountyboe.org/staff
# 526
# https://lhs.davidson.k12.nc.us/apps/staff/
# 527
# https://lhs.dcsdschools.org/staff_directory
# 528
# https://ewhs.edmonds.wednet.edu/directory
# 529
# https://lhs.edmonds.wednet.edu/directory
# 530
# https://lhs.iberiaschools.org/48760_1
# 531
# https://lhs.jcboe.org/apps/staff/
# 532
# https://jeffersondavis.gabbarthost.com/228493_2?personID=180447
# 533
# https://lhs.lafayette.k12.fl.us/Staff
# 534
# https://lhs.lake.k12.fl.us/teachers
# 535
# https://lhs.lakelandsd.org/apps/staff/
# 536
# https://lhs.lancastercsd.com/staff-directory
# 537
# https://lchs.lapeerschools.org/staff_directory
# 538
# https://www.laurel.k12.mt.us/departments/human-resources/human-resources-staff-directory
# 539
# https://www.lcsc.k12.in.us/o/logansport-community-school-corporation/staff?filter=42038
# 540
# https://lhs.ledyard.net/contact_us/staff_directory
# 541
# https://lhs.leoniaschools.org/apps/staff/
# 542
# https://lhs.lewistonpublicschools.org/en-US/staff
# 543
# https://lhs.lexingtonisd.net/apps/staff/
# 544
# https://lhs.libertyisd.net/
# 545
# https://lhs.lindenusd.com/apps/pages/index.jsp?uREC_ID=1458527&type=d&pREC_ID=1643178
# 546
# https://lhs.livingstonisd.com/86499_2
# 547
# https://lhs.lockhartisd.org/about-us/staff-directory
# 548
# https://lhs.longmeadow.k12.ma.us/academics/directory-faculty-staff
# 549
# https://portal.tssaa.org/common/directory/?id=301
# 550
# https://lhs.lyfordcisd.net/apps/pages/index.jsp?uREC_ID=3337565&type=d
# 551
# https://echs.muhsd.org/echs/library/library-staff-and-contact
# 552
# https://lhs.muhsd.org/lhs/directory
# 553
# https://lhs.pickens.k12.sc.us/o/lhs/staff
# 554
# https://wvde.state.wv.us/ed_directory/index.html?county_id=74&school_id=503
# 555
# https://lhs.sau88.net/m/staff/
# 556
# https://lhs.scott.k12.ms.us/apps/staff/
# 557
# https://lhs.sumterschools.net/school-information/directory/
# 558
# https://lhs.tangischools.org/directory
# 559
# https://www.walkerschools.org/about-us/staff-directory
# 560
# https://lhs.websterpsb.org/142300_2
# 561
# https://libbyschools.org/lmhs-staff/
# 562
# https://liberty.isd411.org/staff
# 563
# https://www.licking.k12.mo.us/staff
# 564
# https://lifeschool.net/contact-information/lmsoc-staff-directory
# 565
# https://lifeschool.net/contact-information/lhsw-staff-directory
# 566
# https://www.cde.ca.gov/schooldirectory/details?cdscode=01612590130633
# 567
# https://lincoln.portangelesschools.org/staff
# 568
# https://lincoln.tacomaschools.org/contact
# 569
# https://lincolnhs.seattleschools.org/staff/
# 570
# https://lincolnprep.greatheartsamerica.org/faculty-staff/
# 571
# https://lincolnprep.wildapricot.org/Team
# 572
# https://lindblomeagles.org/m/staff/
# 573
# https://lindhurst.mjusd.com/Staff-Directory/index.html
# 574
# https://www.zoominfo.com/pic/hyde-leadership-charter-school/94848468
# 575
# https://lisahybrid.lisaacademy.org/apps/pages/index.jsp?uREC_ID=2159296&type=d&pREC_ID=staff
# 576
# https://lisanorthhigh.lisaacademy.org/apps/staff
# 577
# https://lisbonhs.ss16.sharpschool.com/staff_directory_
# 578
# https://littletonpublicschools.net/schools/arapahoe-high-school/administration
# 579
# https://asuprep.asu.edu/contact-us/
# 580
# https://liveoakclassical.com/about/faculty-staff/
# 581
# https://www.cde.ca.gov/schooldirectory/details?cdscode=36679340137638
# 582
# https://ollakers.org/staff
# 583
# https://lmhs.tcisd.org/about/directory
# 584
# https://lne.lps.org/directory/
# 585
# https://lochravenhs.bcps.org/staff/staff_directory
# 586
# https://loganhigh.org/alphabetical-directory
# 587
# https://loganhigh.org/new-page-1
# 588
# https://lohs.cjuhsd.net/apps/pages/index.jsp?uREC_ID=1769642&type=d
# 589
# https://lomahs.org/apps/staff
# 590
# https://lompochighschool.lusd.org/staff/staff-directory
# 591
# https://dcps.duvalschools.org/domain/3171
# 592
# https://www.lonestarschool.net/staff
# 593
# https://loslunasllhs.ss13.sharpschool.com/school_info/staff_directory
# 594
# https://loslunasvhs.ss13.sharpschool.com/school_info/staff_directory
# 595
# https://louisvillecollegiate.org/staff-directory/
# 596
# https://lph.highlands.k12.fl.us/about-lph/faculty-and-staff
# 597
# https://lphs-hlpusd-ca.schoolloop.com/directory
# 598
# https://cvhs.alpineschools.org/faculty-staff/
# 599
# https://lphs.lincolnparkpublicschools.com/apps/staff/
# 600
# https://lphs.lpcsc.k12.in.us/en-US/staff
# 601
# https://lppacs.org/category/teacher_profile/
# 602
# https://lrhs.lakeregionschools.org/en-US/staff
# 603
# https://lsak12.com/faculty-staff/
# 604
# https://lsh.leeschools.net/staff_directory
# 605
# https://lshs.dcssga.org/about/staff_directory
# 606
# https://lshs.lakeshoreschools.org/staff_directory
# 607
# https://lsuu.org/schools/peoples-academy/faculty-staff/
# 608
# https://lswhs.lsr7.org/staff/
# 609
# https://lswhs.lsr7.org/staff/
# 610
# https://luhs.lnsd.org/directory
# 611
# http://www.lutheranhighschool.net/faculty--staff.html
# 612
# https://lutherburbank.scusd.edu/staff
# 613
# https://lvhs.lavegaisd.org/about/campus-staff-directory
# 614
# https://lvmhs.hcde.org/directory/staff
# 615
# https://www.cde.ca.gov/schooldirectory/details?cdscode=36750513630563
# 616
# https://lwhs.kusd.org/about/staff-directory
# 617
# https://ehs.lwsd.org/about-us/staff-directory-new
# 618
# https://lwhs.lwsd.org/about-us/staff-directory
# 619
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37684113731304
# 620
# https://www.mabears.net/m/staff/
# 621
# https://www.facebook.com/Magnet.Academy.for.Cultural.Arts/
# 622
# https://macduffie.org/faculty-staff
# 623
# https://machi.miltfree.k12.or.us/quicklinks/staff-directory
# 624
# https://maconeast.net/category/employee/staff-directory/
# 625
# https://www.zoominfo.com/pic/macon-road-baptist-school/64865364
# 626
# https://mmhs.madawaskaschools.org/en/staff
# 627
# https://madison.sandiegounified.org/academics/physical_education_health/staff
# 628
# https://madisonhighlandprep.com/contact-us/faculty-list/
# 629
# https://madisonhs.fcps.edu/about/administration
# 630
# https://profiles.doe.mass.edu/profiles/general.aspx?topNavId=1&orgcode=00350537&orgtypecode=6&leftNavId=122&
# 631
# https://maghs.simpson.k12.ms.us/en/staff
# 632
# https://magiccitycampus.minot.k12.nd.us/en-US/staff
# 633
# https://magnolia.auhsd.us/Magnolia/Staff/
# 634
# https://mahs.mpusd.net/apps/pages/index.jsp?uREC_ID=1381758&type=d
# 635
# https://makualani.com/staff/
# 636
# https://maldenps.org/high/staff-directory/
# 637
# https://malone.jcsb.org/apps/staff/
# 638
# https://manncs.gseis.ucla.edu/staff/
# 639
# https://mansfieldstpeters.org/school/staff/
# 640
# https://manual.dpsk12.org/staff/
# 641
# https://manzano.aps.edu/contact-us
# 642
# https://maplewood.mnps.org/our_school/directory
# 643
# https://marcelluscs.org/schools/high-school/staff-directory/
# 644
# https://www.cde.ca.gov/schooldirectory/details?cdscode=34674210137950
# 645
# https://markmorris.longviewschools.com/staff-directory
# 646
# https://markwestcharter.org/staff/
# 647
# https://marquettecatholic.com/staff-directory
# 648
# https://marshallhs.fcps.edu/about/staff-directory
# 649
# https://marshfield.cbd9.net/apps/staff/
# 650
# https://marshill.edu/about/our-team/faculty-and-staff/
# 651
# https://marysville.mjusd.com/staff-directory/
# 652
# https://mvrhs.mascomaschools.org/our_school/mvrhs_staff_directory
# 653
# https://masonacademy.com/m/staff/
# 654
# https://mastbaum.philasd.org/contact-us/
# 655
# https://masterman.philasd.org/about-us/faculty/
# 656
# https://masterman.philasd.org/about-us/faculty/
# 657
# https://masterycharter.org/staff/
# 658
# https://masterycharter.org/secondary-schools/mastery-high-school-of-camden
# 659
# https://masterycharter.org/staff/
# 660
# https://masterycharter.org/staff/
# 661
# https://masterycharter.org/staff/
# 662
# https://mauhs.svsu.org/apps/staff/
# 663
# https://www.mayfield.kyschools.us/apps/staff/
# 664
# https://www.tabernaclechristian.org/administration-and-school-staff/
# 665
# https://mca.mcintosh.k12.ga.us/Faculty
# 666
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647250127381
# 667
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647250127381
# 668
# https://miamicarolcityshs.net/
# 669
# https://www.mccroryschools.org/staff
# 670
# https://mccsedu.org/teachers-2/staff-administrators/
# 671
# https://mchs-lausd-ca.schoolloop.com/staff
# 672
# https://mchs-santarosa-ca.schoolloop.com/cms/page_view?d=x&piid=&vpid=1405339251838
# 673
# https://mchs.madison.k12.fl.us/school-administration
# 674
# https://mchs.massac.org/staff-directory
# 675
# https://mchs.mcisd.net/apps/staff/
# 676
# https://mchs.mcstn.net/en-US/staff
# 677
# https://mchs.mitchell.k12.ga.us/apps/staff/
# 678
# https://www.morgan.kyschools.us/resources/staff
# 679
# https://mckeecths.org/contact-the-staff/
# 680
# https://mckinleyvillehighschool.nohum.org/apps/staff/
# 681
# https://mclain.jeffcopublicschools.org/staff
# 682
# https://mclain.tulsaschools.org/connect-with-us
# 683
# https://patrioths.pwcs.edu/staff
# 684
# https://www.millingtonschools.org/staff_directory
# 685
# https://www.mcboe.net/
# 686
# https://mcpsweb.org/?page_id=28912
# 687
# https://mcpsweb.org/?page_id=28930
# 688
# https://mcscs.org/administrationandstaff/
# 689
# https://mcseagles.net/about-us/faculty-staff/
# 690
# https://www.mercer.kyschools.us/staff
# 691
# https://mcsk12nm.org/apps/staff/
# 692
# https://mcsshs.ss7.sharpschool.com/faculty
# 693
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331935717
# 694
# https://www.qacps.org/staff/staff-directory/
# 695
# https://www.cde.ca.gov/schooldirectory/details?cdscode=07617540734566
# 696
# https://mdo.dadeschools.net/
# 697
# https://meca.misdtx.net/apps/pages/index.jsp?uREC_ID=1606371&type=d&pREC_ID=1735965
# 698
# https://medinavalleyhs.mvisd.com/apps/staff/
# 699
# https://mehs.meusd.org/Contact/Staff-Directory/index.html
# 700
# https://mhs.springbranchisd.com/about/contact-us
# 701
# https://sites.google.com/a/mansd.org/memorial/about/directory/administration-offices
# 702
# https://www.mcallenisd.org/o/memorialhs/staff
# 703
# https://memorial.edmondschools.net/faculty/faculty-list-alphabetical/
# 704
# https://portal.tssaa.org/common/directory/?id=346
# 705
# https://mville.nn.k12.va.us/faculty.html
# 706
# https://mendhs.simpson.k12.ms.us/en-US/staff
# 707
# https://mesagrandeacademy.org/about/faculty/
# 708
# https://methow.org/schools/liberty-bell-jr-sr-high/lb-staff/
# 709
# https://www.schools.nyc.gov/schools/Q167
# 710
# https://www.mexicoschools.net/for_staff
# 711
# https://mfhs.mfschools.net/staff
# 712
# https://bpcsd.ss18.sharpschool.com/schools/maple_grove/staff_directory
# 713
# https://www.mg.k12.mo.us/district_links/district_information/district_administration
# 714
# https://mglva.k12.com/about-our-school/meet-our-team/meet-our-administrators.html
# 715
# https://mgm.vistausd.org/contact_us/office_staff
# 716
# https://mhhs.gladesedu.com/o/mhhs/staff
# 717
# https://mhhs.lammersvilleschooldistrict.net/apps/staff/
# 718
# https://mhhse.hcboe.net/facultystafflist
# 719
# https://mhhsw.hcboe.net/facultystaff
# 720
# https://mhs-mvths.mps02155.org/about/staff-directory
# 721
# https://mhs.avoyellespsb.com/
# 722
# https://mhs.cherokee.k12.nc.us/apps/staff/
# 723
# https://mhs.cpsbla.us/apps/staff/
# 724
# https://www.crawfordschools.org/apps/staff/
# 725
# https://mhs.crsk12.org/about-us/contact-us
# 726
# https://mhs.davis.k12.ut.us/faculty-staff
# 727
# https://mhs.hcsedu.org/33901_1
# 728
# https://mhs.inglewoodusd.com/apps/staff/
# 729
# https://mhs.jcboe.org/apps/staff/
# 730
# https://mhs.jcsb.org/apps/staff/
# 731
# https://mhs.lcps.net/
# 732
# https://wvde.state.wv.us/ed_directory/index.html?county_id=45&school_id=503
# 733
# https://mhs.madisonpsb.org/20905_1
# 734
# https://mhs.malvernleopards.org/83110_2
# 735
# https://www.marlboro.k12.sc.us/staff
# 736
# https://mhs.martinsville.k12.va.us/o/mhs/staff
# 737
# https://www.mayflower.school/page/employees
# 738
# https://www.mccomb.k12.ms.us/apps/pages/index.jsp?uREC_ID=1196986&type=d&pREC_ID=1438657
# 739
# https://www.co.middlesex.va.us/directory.aspx?did=6
# 740
# https://mhs.mcssga.org/office-staff/
# 741
# https://mhs.miami.k12.ok.us/staff_directory
# 742
# https://mhs.midland-7.net/
# 743
# https://mhs.milfordk12.org/apps/staff/
# 744
# https://mhs.millburn.org/apps/staff/
# 745
# https://mhs.miller.k12.ga.us/staffdirectory
# 746
# https://mhs.millville.org/apps/staff
# 747
# https://mhs.misdtx.net/apps/pages/index.jsp?uREC_ID=1640680&type=d&pREC_ID=1783335
# 748
# https://mhs.monroe.k12.al.us/staff_directory
# 749
# https://mhs.monroeps.org/students/staff_directory
# 750
# https://mhs.morgansd.org/258888_2
# 751
# https://mhs.msd3.org/staff
# 752
# https://mhs.mtps.com/for_staff/staff_directory
# 753
# http://www.mufsd.com/departments/staff_directory
# 754
# http://www.mufsd.com/departments/staff_directory
# 755
# https://mhs.musdaztecs.com/apps/staff/
# 756
# https://mhs.mwpisd.esc18.net/24976_2
# 757
# https://mhs.nclack.k12.or.us/about-us/staff-directory
# 758
# https://www.mlsd.us/StaffDirectory1.aspx
# 759
# https://mhs.pcssd.org/o/maumelle-high-school/staff
# 760
# https://ppsk12.us/cms/One.aspx?portalId=797350&pageId=2221186
# 761
# https://portal.tssaa.org/common/directory/?id=335
# 762
# https://mhs.scott.k12.ms.us/apps/pages/index.jsp?uREC_ID=1349012&type=d&pREC_ID=1538884
# 763
# https://hhs.tsc.k12.in.us/about-us/directory
# 764
# https://mhs.websterpsb.org/328211_2
# 765
# https://www.schools.nyc.gov/schools/K583
# 766
# https://mhsfins.com/teachers
# 767
# https://www.a2schools.org/Page/689
# 768
# https://www.miamiartscharter.net/apps/staff/
# 769
# https://miamisunsetsenior.com/staff-directory/
# 770
# https://www.zoominfo.com/pic/conner-creek-east/28774528
# 771
# https://www.micheleclark.org/m/staff/
# 772
# https://www.hflcsd.org/staff/
# 773
# https://middlecollege.cmcss.net/directory/
# 774
# https://middlecollege.lodiusd.net/staff-directory
# 775
# https://middlecollege.sbcusd.com/staff-directory
# 776
# https://www.sauguscenturions.com/apps/staff/
# 777
# https://www.midlandisd.net/domain/6098
# 778
# https://www.daltonpublicschools.com/directory
# 779
# https://milfordmillhs.bcps.org/home/staff_directory
# 780
# https://miller.ccisd.us/directory
# 781
# https://mills.pcssd.org/o/wilbur-d-mills-hs/staff
# 782
# https://www.milton.k12.wi.us/schools/high/mhsstaff.cfm
# 783
# https://docs.google.com/spreadsheets/d/1wb00JXpHqtuJ54PbEnGIlIdwWj29Rc7nENSGIYFJzDY/edit
# 784
# https://minarets.chawanakee.k12.ca.us/apps/pages/index.jsp?uREC_ID=2519317&type=d
# 785
# https://www.cde.ca.gov/schooldirectory/details?cdscode=36750440114389
# 786
# https://miscmv.org/students/teacher-contacts/
# 787
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19753090137786
# 788
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19651360114439
# 789
# https://mkchs.com/about/faculty-staff-directory/
# 790
# https://mlhs.mlsd.org/apps/staff/
# 791
# https://mlk.dpsk12.org/about/faculty-staff/
# 792
# https://mlk.mnps.org/our_school/directory
# 793
# https://mlkhs.philasd.org/faculty-and-staff/
# 794
# https://mlnda.buncombeschools.org/o/mlnda/staff
# 795
# https://www.geneseeisd.org/staff_directory/mmc
# 796
# https://mmhs.nebo.edu/faculty
# 797
# https://mmrhs.bhrsd.org/staff/
# 798
# https://mmrhs.bhrsd.org/staff/
# 799
# https://mms.pocahontas.k12.wv.us/
# 800
# https://mms.wyom.k12.wv.us/
# 801
# https://mnhs.mnsd.org/about-us/departments-staff
# 802
# https://mnohs.org/why-choose-mnohs/faculty-and-staff/
# 803
# https://mo02207039.schoolwires.net/site/Default.aspx?PageType=1&SiteID=43&ChannelID=44&DirectoryType=6
# 804
# https://mocfv.org/index.php/high-school-staff-directory/
# 805
# https://mohs.k12albemarle.org/directory
# 806
# https://www.monroe.k12.mi.us/MHS/Staff/
# 807
# https://monroecentral.org/jr-sr-high-staff/
# 808
# https://www.dcismontbello.org/staff_faculty/
# 809
# https://www.montcalm.edu/about/leadership/staff-faculty-directory/
# 810
# https://montebello-vhs.edlioschool.com/apps/staff/
# 811
# https://monarchs.guhsd.net/
# 812
# https://montgomerycatholic.org/staff/
# 813
# https://montgomerycentralhigh.cmcss.net/directory/
# 814
# https://montgomerycentralhigh.cmcss.net/directory/
# 815
# https://mvasports.com/staff-directory
# 816
# https://moody.ccisd.us/directory
# 817
# https://www.jefferson.kyschools.us/schools/profiles/moore-traditional
# 818
# https://morrisschools.net/195519_2
# 819
# https://www.schools.nyc.gov/schools/X128
# 820
# https://mountainlakeps.ss10.sharpschool.com/staff_directory
# 821
# https://boe.monroe.k12.wv.us/o/mvs/staff
# 822
# https://mountalverniahs.org/about/directory/name/deborah-brancato/
# 823
# https://mountmichael.com/faculty-staff/
# 824
# https://mountmiguel.guhsd.net/School-Info/Staff-Directory/index.html
# 825
# https://mountvernonschool.org/important-contacts/
# 826
# https://mpa.csalcharterschools.org/m/staff/
# 827
# https://www.mpark.net/resources/for_staff
# 828
# https://mphs.mpsdnow.org/apps/staff/
# 829
# https://mphs.qcschools.com/
# 830
# https://schools.milwaukee.k12.wi.us/audubon/about/staff-directory/
# 831
# https://schools.milwaukee.k12.wi.us/bradleytech/staff/
# 832
# https://schools.milwaukee.k12.wi.us/rkims/staff/
# 833
# https://schools.milwaukee.k12.wi.us/macdowell/staff/
# 834
# https://schools.milwaukee.k12.wi.us/marshall/staff/
# 835
# https://schools.milwaukee.k12.wi.us/north/staff/
# 836
# https://schools.milwaukee.k12.wi.us/obama/staff/
# 837
# https://schools.milwaukee.k12.wi.us/south/staff/
# 838
# https://schools.milwaukee.k12.wi.us/wcll/staff/
# 839
# https://schools.milwaukee.k12.wi.us/hamilton/about/staff/
# 840
# https://mrh.leeschools.net/our_school/administration_and_faculty/staff
# 841
# https://mrhs.highlineschools.org/staff-directory
# 842
# https://mrhs.mr238.org/staff_directory
# 843
# https://mrhs.wsd3.org/staff
# 844
# https://ms.hicksvillepublicschools.org/middle_school/contact_information
# 845
# https://ms.pawlingschools.org/directory/faculty
# 846
# https://www.schools.nyc.gov/schools/M131
# 847
# https://www.schools.nyc.gov/schools/K354
# 848
# https://ms839.org/our-team/
# 849
# https://msa2.magnoliapublicschools.org/m/staff/
# 850
# https://idhsaa.org/school?id=36acdd0d-a5d6-41a2-aff9-5c9a944d5284
# 851
# https://msdofmartinsville.org/martinsville-high-school/about-us/our-staff/
# 852
# https://www.durand.k12.wi.us/staff
# 853
# https://www.m-ecs.org/staff
# 854
# https://www.m-ecs.org/staff
# 855
# https://www.monessenschooldistrict.com/apps/staff/
# 856
# https://mshs.scsb.org/
# 857
# https://mshs.somersetskypointe.org/m/staff/
# 858
# https://mshs.westsiouxschools.org/en-US/staff
# 859
# https://mst.mansd.org/o/mst/staff?page_no=3
# 860
# https://mt.tacomaschools.org/contact
# 861
# https://mt01001320.schoolwires.net/site/Default.aspx?PageType=1&SiteID=1&ChannelID=16&DirectoryType=6
# 862
# https://mta.mausd.org/apps/staff/
# 863
# https://mtabram.msad58.org/apps/staff/
# 864
# https://mtcarmelacademy.net/school-staff/
# 865
# https://mtmadonna.gilroyunified.org/our-staff
# 866
# https://mtscott.org/who-we-are/
# 867
# https://sites.muscogee.k12.ga.us/carverhigh/employees/
# 868
# https://sites.muscogee.k12.ga.us/jordan/faculty-staff/
# 869
# https://sites.muscogee.k12.ga.us/kendrick/staff/
# 870
# https://muscogee.k12.ga.us/Schools/SHW
# 871
# https://sites.muscogee.k12.ga.us/spencer/staff-2/
# 872
# https://muskegoncatholic.org/about/meet-our-faculty-staff/
# 873
# https://muskegonpublicschools.org/schools/muskegon-high-school/staff-directory/
# 874
# https://mvca.k12.com/about-our-school/meet-our-team/staff.html
# 875
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37684113733953
# 876
# https://mvhs.mississinawa.k12.oh.us/
# 877
# https://mvhs.mtvernoncsd.org/our-school/staff-directory
# 878
# https://mvhs.mvsdpride.org/staff-directory
# 879
# https://mvhs.uinta4.com/faculty
# 880
# https://mvsteam.mtvernoncsd.org/our-school/staff-directory
# 881
# https://mwhs.mwisd.net/apps/staff/
# 882
# https://www.fiu.edu/information-for/faculty-staff.html
# 883
# https://myips.org/crispusattucks/staff-directory/
# 884
# https://myips.org/georgewashington/staff-directory/
# 885
# https://myips.org/shortridge/staff-directory/
# 886
# https://mylogos.org/administrative-staff
# 887
# https://mynderseacademy.senecafallscsd.org/parents/staff-directory
# 888
# https://mzh.carrollcountyschools.com/staffdirectory1
# 889
# https://nahighschool.com/faculty/
# 890
# https://nampahigh.nsd131.org/apps/staff/
# 891
# https://www.nanakuligoldenhawks.org/apps/staff/
# 892
# https://www.napoleonschools.org/staff
# 893
# https://nashcentralhs.ncpschools.net/
# 894
# https://natomasunified.org/nhs/staff/
# 895
# https://www.cde.ca.gov/schooldirectory/details?cdscode=34752830120113
# 896
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647330129585
# 897
# https://kippstl.org/apps/staff/
# 898
# https://www.linkedin.com/school/naya-early-college-academy/
# 899
# https://nbhs.newbedfordschools.org/staff
# 900
# https://nbhs.northbranfordschools.org/en-US/staff
# 901
# https://www.onslow.k12.nc.us/Page/10143
# 902
# https://www.ashevillecityschools.net/domain/155
# 903
# https://www.ashevillecityschools.net/domain/777
# 904
# https://www.northampton.k12.nc.us/domain/217
# 905
# https://ncaknights.com/staff/
# 906
# https://ncchs.d187.org/o/ncchs/staff
# 907
# https://www.lyndonvillecsd.org/staff
# 908
# https://www.nebcityps.org/o/nebraska-city-high-school/staff
# 909
# https://www.nelsoncntyschs.ky.schools.bz/2/Staff
# 910
# https://sites.google.com/a/ncsuvt.org/north-country-career-center--ncsuvt/faculty
# 911
# https://ncvps.org/our-staff/
# 912
# https://ndaacademy.org/about-us/school-directory/
# 913
# https://ndhs.decaturco.k12.in.us/Teachers-and-Staff
# 914
# https://www.bie.edu/schools/directory/standing-rock-community-school
# 915
# https://www.zoominfo.com/pic/notre-dame-high-school-of-acadia-parish/354575687
# 916
# https://nec.dpsk12.org/about/faculty-staff-directory/
# 917
# https://negaunee.k12.mi.us/nhs-teacher-directory
# 918
# https://neh.lauderdale.k12.ms.us/apps/staff/
# 919
# https://nehs.ecps.us/apps/staff/
# 920
# https://www.nelsd.org/
# 921
# https://nej.jonesk12.org/en-US/staff
# 922
# https://neocollegeprep.org/about/
# 923
# https://nettlecreekschools.com/hjshs/contact/staff-directory/
# 924
# https://nettletonschools.net/staff-directory
# 925
# https://newamericaschoolnm.org/nas-albuquerque-staff/
# 926
# ...
# 1868
# https://www.uticak12.org/eisenhower
# 1869
# https://www.stewartcreekhs.com/apps/staff/
# 1870
# https://stgacademy.org/faculty/
# 1871
# https://sths.gisd.k12.nm.us/339664_2
# 1872
# https://stignace.eupschools.org/staff
# 1873
# https://stjameshs.sharpschool.net/staff_directory/administrative_staff
# 1874
# https://stjosephchristian.com/about/faculty-and-staff/
# 1875
# https://stjosephhs.org/general-information/staff/
# 1876
# https://stone.ccboe.com/about/administrative-team
# 1877
# https://stpatschool.com/facultystaff/
# 1878
# https://stpetersboyshs.org/about/facultystaff-directory/
# 1879
# https://strathmore.portervilleschools.org/apps/staff/
# 1880
# https://striveprep.org/wp-content/uploads/2020/01/RISE-Staff-Directory-for-Site-Sheet1-2-Niria-Quinones.pdf
# 1881
# https://striveprep.org/wp-content/uploads/2020/01/RISE-Staff-Directory-for-Site-Sheet1-2-Niria-Quinones.pdf
# 1882
# https://www.sturgisps.org/directory/sturgis_high_school_staff_directory
# 1883
# https://sumitonchristian.org/directory.php
# 1884
# https://summerfieldwaldorf.org/staff/
# 1885
# https://dsusdsummit.ss18.sharpschool.com/staff_directory
# 1886
# https://summit.school/
# 1887
# https://summiteagles.org/faculty/
# 1888
# https://summitlearningcharter.org/about-us/contact-us/
# 1889
# https://summitps.org/our-schools/summit-tahoma-san-jose/contact-summit-tahoma/
# 1890
# https://summitps.org/our-schools/summit-atlas-west-seattle/contact-summit-atlas/
# 1891
# https://www.cde.ca.gov/schooldirectory/details?cdscode=41690620119503
# 1892
# https://summitps.org/our-schools/summit-olympus-tacoma/contact-summit-olympus/
# 1893
# https://summitps.org/our-schools/summit-sierra-seattle/contact-summit-sierra/
# 1894
# https://sunedhigh.com/ft-lauderdale-faculty-staff/
# 1895
# https://sunedhigh.com/margate-faculty-staff/
# 1896
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647336061600
# 1897
# https://susd12.org/22/star/
# 1898
# https://susd30.us/schools/sahuarita-high-school/staff/
# 1899
# https://susd30.us/schools/walden-grove-high-school/staff/
# 1900
# https://www.suusuccess.org/faculty-and-staff/
# 1901
# https://www.suu.edu/facstaff/
# 1902
# https://svbluedevils.org/jr%2Fsr-high-school
# 1903
# https://svhs.sad55.org/en-US/staff
# 1904
# https://svhs.scottsvalleyusd.org/o/svhs/page/staff-directory
# 1905
# https://svhs.wayn.k12.wv.us/staff/?page_no=2
# 1906
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19651281995653
# 1907
# https://sweethome.k12.or.us/staff-directory/
# 1908
# https://swehs.ecps.us/apps/staff/
# 1909
# https://swenson.philasd.org/faculty/
# 1910
# https://www.sw.wednet.edu/connect/staff-directory
# 1911
# https://swhsmarengoal.schoolinsites.com/contact
# 1912
# https://www.swissohio.k12.oh.us/monroe-central-high-school/staff-directory-7/staff-directory-5/
# 1913
# https://swissohio.k12.oh.us/staff-directory/river-high-school-3/
# 1914
# https://swrhs.randolph.k12.nc.us/meetourstaff
# 1915
# https://sws.seattleschools.org/staff/
# 1916
# https://taconic.pittsfield.net/staff_directory/administrative_staff
# 1917
# https://talley.rentonschools.us/our-school/faculty
# 1918
# https://talmudicalacademy.org/faculty/
# 1919
# https://tapestryschool.org/about-tapestry/administration-teachers/
# 1920
# https://www.taylor.k12.fl.us/staffdirectory
# 1921
# https://tbirdterritory.com/apps/staff/
# 1922
# https://www.tcawarriors.org/our-team/
# 1923
# https://tcchs.todd.kyschools.us/apps/staff/
# 1924
# https://tcchs.troy.k12.mi.us/about-tcchs/tcchs-staff-directory
# 1925
# https://www.cde.ca.gov/schooldirectory/details?cdscode=37684526987002
# 1926
# https://tchs.taylor.kyschools.us/about-us/facultystaff-directory
# 1927
# https://tchs.tcisd.org/about/directory
# 1928
# https://www.telfairschools.org/staff
# 1929
# https://www.toombscountyschools.org/staff/
# 1930
# https://tchs.trigg.kyschools.us/faculty-staff-directory
# 1931
# https://tcjshs.tellcity.k12.in.us/resources
# 1932
# https://taylorcountytcms.ss10.sharpschool.com/staff_directory
# 1933
# https://tcusd.org/tchs/tchs-staff-directory/
# 1934
# https://techhigh.us/learn-more/faculty/
# 1935
# https://www.cde.ca.gov/schooldirectory/details?cdscode=40688414037701
# 1936
# https://tenor.seedsofhealth.org/apps/staff/departmental.jsp
# 1937
# https://tepcharter.org/teachers-leaders/
# 1938
# https://terrawolves.com/apps/staff/
# 1939
# https://texomachristian.org/staff/
# 1940
# https://theambroseschool.org/about/staff2/
# 1941
# https://theatonementacademy.org/our-team
# 1942
# https://www.cde.ca.gov/schooldirectory/details?cdscode=15636280134312
# 1943
# https://www.schools.nyc.gov/schools/X478
# 1944
# https://theclintonschool.net/factulty-staff
# 1945
# https://theevca.com/directory/
# 1946
# https://thelinc.philasd.org/staff-directory/
# 1947
# https://themapacademy.org/about-map/leadership/
# 1948
# https://themsms.org/directory/
# 1949
# https://theoakscca.org/staff-contact-information/
# 1950
# https://theodorerooseveltdc.org/m/staff/
# 1951
# https://www.rooseveltstay.org/facultyandstaff
# 1952
# https://therocklions.com/our-vision/our-staff/
# 1953
# https://www.thesccs.org/leadership/our_team
# 1954
# https://thesugarcreek.org/about/school-directory
# 1955
# https://thevanguardschool.com/home/about_us/the_vanguard_team/
# 1956
# https://thh.gmcs.org/
# 1957
# https://thomassumteracademy.org/faculty-administration/
# 1958
# https://thorntonh.adams12.org/our-school/staff-directory
# 1959
# https://www.cde.ca.gov/schooldirectory/details?cdscode=01611920138339
# 1960
# https://ths.alpineschools.org/faculty-staff/
# 1961
# https://ths.carrollcountyschools.com/schoolemployee
# 1962
# https://ths.ecps.us/apps/staff/
# 1963
# https://ths.mcduffie.k12.ga.us/apps/staff/
# 1964
# https://ths.plymouth.k12.ct.us/about/directory
# 1965
# https://ths.randolph.k12.nc.us/mos
# 1966
# https://ths.tcs.k12.nc.us/apps/staff/
# 1967
# https://ths.tcsedu.net/about-us/administration
# 1968
# https://ths.tcusd3.org/staff/?page_no=3
# 1969
# https://ths.tombstoneschools.org/en-US/staff
# 1970
# https://ths.topekapublicschools.net/staff
# 1971
# https://torringtonths.ss16.sharpschool.com/staff_directory
# 1972
# https://www.trico176.org/en-US/staff
# 1973
# https://ths.trinityisd.net/apps/staff/
# 1974
# https://ths.trionschools.org/staff
# 1975
# https://profiles.doe.mass.edu/profiles/general.aspx?topNavId=1&orgcode=07730505&orgtypecode=6&leftNavId=122&
# 1976
# https://ths.tsd401.org/administration/staff-directory/
# 1977
# https://wvde.state.wv.us/ed_directory/index.html?county_id=89&school_id=507
# 1978
# https://thurston.southredford.org/apps/staff/
# 1979
# https://tierradelsol.kernhigh.org/apps/staff/
# 1980
# https://tilden.cps.edu/m/staff/
# 1981
# https://timberline.boiseschools.org/our_school/staff_directory
# 1982
# https://www.timothychristian.com/about/staff
# 1983
# https://tjhs.dpsk12.org/directory/
# 1984
# https://tjhs.rvaschools.net/about-us/contact-us/staff-directory
# 1985
# https://tlschools.org/staff_directory/twin-lakes-high-school-directory
# 1986
# https://tmhs.tellurideschool.org/staff_directory
# 1987
# https://tmhs.thompsonk12.org/apps/staff/
# 1988
# https://www.zoominfo.com/pic/the-masters-program/347467768
# 1989
# https://portal.tssaa.org/common/directory/?id=134
# 1990
# https://www.nelsoncntyschs.ky.schools.bz/1/staff
# 1991
# https://tolcs.org/leadership-and-staff/
# 1992
# https://toltoncatholic.org/faculty-and-staff-directory/
# 1993
# https://tooelehigh.tooeleschools.org/staff
# 1994
# https://towsonhs.bcps.org/faculty___staff
# 1995
# https://tphs.monroe.k12.tn.us/apps/staff/
# 1996
# https://trace.sandiegounified.org/contact_us/trace_staff_directory
# 1997
# https://traice.tulsaschools.org/about-us
# 1998
# https://traip.kitteryschools.com/
# 1999
# https://www.zoominfo.com/pic/transit-tech-cte-high-school/368804785
# 2000
# https://treca.org/staff
# 2001
# https://trentoncatholicprep.org/directory
# 2002
# https://tri-county.us/contact-us/
# 2003
# https://tricityprep.org/home-page/faculty/
# 2004
# https://trinityacademy.com/about-us/faculty-and-staff/
# 2005
# https://trinitygreenlawn.org/about/faculty/
# 2006
# https://trinityriverridge.org/about/faculty/
# 2007
# https://trinityschooloftexas.com/about/meet-the-faculty-staff/
# 2008
# https://triumph.laramie1.org/
# 2009
# https://www.nysed.gov/charter-schools/kipp-troy-prep-charter-school
# 2010
# https://tsa.tomballisd.net/staff-directory
# 2011
# https://tsd1.org/contact-us-3/
# 2012
# https://tvhs.smusd90.org/Staff
# 2013
# https://twain.sandiegounified.org/meet_the_staff
# 2014
# https://twhs.topekapublicschools.net/about_us/meet_the_staff
# 2015
# https://tx02205734.schoolwires.net/pac
# 2016
# https://tyee.highlineschools.org/staff-directory
# 2017
# https://tyneracademy.hcde.org/school_staff
# 2018
# https://tywlsqueens.com/
# 2019
# https://www.uachs.org/apps/staff/
# 2020
# https://ucacademy.org/high-school/faculty/
# 2021
# https://uchs.sandiegounified.org/staff
# 2022
# https://uchs.ucps.org/staff_directory
# 2023
# https://udasd.org/contact-us/
# 2024
# https://education.illinoisstate.edu/faculty_staff/list.php?dept=University+High+School&heading=University+High+School
# 2025
# https://uhs.dcsd.org/
# 2026
# https://uhs.lake.k12.fl.us/teachers
# 2027
# https://uhs.ucfsd.org/directory
# 2028
# https://uintah.ss12.sharpschool.com/district_directory/uintah_school_district_staff_directory
# 2029
# https://www.schools.nyc.gov/schools/X371
# 2030
# https://ulhs.upson.k12.ga.us/directory/faculty
# 2031
# https://www.uni.illinois.edu/facultystaff
# 2032
# https://unionnorth.org/staff-directory/
# 2033
# https://www.unionpsd.org/m/pages/index.jsp?uREC_ID=309614&type=d&termREC_ID=&pREC_ID=staff
# 2034
# https://unitychristianschool.org/faculty-staff/
# 2035
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331938885
# 2036
# https://university.tuhsd.org/Our_Staff
# 2037
# https://www.bcc.cuny.edu/directories/
# 2038
# https://universityhigh.iusd.org/directory
# 2039
# https://www.upliftparent.org/domain/2706
# 2040
# https://www.upliftparent.org/domain/72
# 2041
# https://uprep.org/faculty-%26-staff
# 2042
# https://uprepschools.com/
# 2043
# https://uprepschools.com/
# 2044
# https://uprepschools.com/
# 2045
# https://upvhs.valueschools.com/apps/pages/teachers-staff
# 2046
# https://www.cde.ca.gov/schooldirectory/details?cdscode=26102640124990
# 2047
# https://urbandove.org/about-us/our-staff/
# 2048
# https://urbandove.org/about-us/our-staff/
# 2049
# https://urs.randolph.k12.nc.us/meetourstaff
# 2050
# https://www.usjbruins.org/about/meet-our-faculty-staff
# 2051
# https://utahonline.org/about/faculty
# 2052
# https://utva.k12.com/about-our-school/meet-our-team.html
# 2053
# https://va01918659.schoolwires.net/domain/181
# 2054
# https://gchs.gcps1.com/apps/staff/
# 2055
# https://www.zoominfo.com/pic/virtual-academy-of-lafourche/358788712
# 2056
# https://valley.jordandistrict.org/about/staff/
# 2057
# https://valverdehigh.valverde.edu/en-US/staff
# 2058
# https://www.zoominfo.com/pic/vanguard-academy/405733858
# 2059
# https://www.schools.nyc.gov/schools/M449
# 2060
# https://vantage.adams12.org/our-school/staff-directory
# 2061
# https://varinahs.henricoschools.us/faculty-staff/
# 2062
# https://veritas.seedsofhealth.org/apps/staff/departmental.jsp
# 2063
# https://veritasschool.net/our-school/faculty-staff/
# 2064
# https://vermillion.k12.sd.us/vermillion-high-school/high-school-staff/
# 2065
# https://valleyheadhighschool.ss18.sharpschool.com/faculty___staff
# 2066
# https://vhs.cpsbla.us/apps/staff
# 2067
# https://vhs.davis.k12.ut.us/faculty-staff
# 2068
# https://vhs.egusd.net/Our-School/General-Info/Staff/index.html
# 2069
# https://vhs.hcbe.net/schoolstaff
# 2070
# https://vhs.valesd.org/home/staff-directory
# 2071
# https://vhs.vallivue.org/apps/pages/index.jsp?uREC_ID=1082825&type=d&pREC_ID=1376666
# 2072
# https://vhs.venusisd.net/en-US/staff
# 2073
# https://www.vernonisd.org/page/staff-resources
# 2074
# https://vhs.vidorisd.org/309213_2
# 2075
# https://vhs.wcsdschools.com/staff
# 2076
# https://www.osceolaschools.net/Page/2944
# 2077
# https://victorycollegeprep.org/staff/
# 2078
# https://victoryhs.aldineisd.org/about/faculty/
# 2079
# https://www.vidaliahighschool.org/directory
# 2080
# https://village.asd20.org/
# 2081
# https://vinal.cttech.org/about/staff-directory/
# 2082
# https://www.virginiamn.us/i_want_to/staff_directory.php
# 2083
# https://capistranovirtual.capousd.org/Staff-Directory/index.html
# 2084
# https://virtualcampus.dmschools.org/about/our-staff/
# 2085
# https://www.hcde.org/contact_us/staff_directory
# 2086
# https://www.cde.ca.gov/schooldirectory/details?cdscode=36677360136937
# 2087
# https://vistapeakprep.aurorak12.org/our-teamour-campus/staff-directory
# 2088
# https://vistawest.kernhigh.org/apps/staff/
# 2089
# https://vjshs.nkasd.com/apps/staff/
# 2090
# https://my.doe.nh.gov/Profiles/PublicReports/PublicReports.aspx?ReportName=getDistrictSchools&DSTID=727
# 2091
# https://vlearn.mnps.org/staff_directory
# 2092
# https://vmh.ccboe.org/o/vmh/staff
# 2093
# https://vms.valhallaschools.org/pdfs/VALHALLA%20MIDDLE%20SCHOOL%20FACULTY%20AND%20STAFF%20Directory%20for%20Website.pdf
# 2094
# https://vphs.epsb.com/22429_1
# 2095
# https://www.cde.ca.gov/schooldirectory/details?cdscode=56105610109900
# 2096
# https://vs.aceroschools.org/apps/staff/
# 2097
# https://vschsd.org/schools/north-high-school/contacts/
# 2098
# https://vvhs.aps.edu/staff-info
# 2099
# https://vvhs.valleyviewsd.org/en-US/staff
# 2100
# https://www.vvisd.net/90264_2
# 2101
# https://vvhs.vvuhsd.org/about-us/administration-support-staff
# 2102
# https://vvhsdawgs.org/apps/staff/departmental.jsp?show=TDE
# 2103
# https://vwhs.visd.net/o/vwhs/staff
# 2104
# https://wabass.mnps.org/
# 2105
# https://wac.copiah.ms/faculty-staff-directory
# 2106
# https://www.wadleigharts.org/apps/staff/
# 2107
# https://wahconah.cbrsd.org/about-us/staff-directory
# 2108
# https://www.wahksd.k12.wa.us/District/Department/11-COVID-19/635-Our-Teachers.html
# 2109
# https://waitehighschool.tps.org/
# 2110
# https://wakefield.apsva.us/staff-directory/
# 2111
# https://walden-school.org/faculty
# 2112
# https://waldorfsandiego.org/our-school/faculty-and-staff/
# 2113
# https://waldport.lincoln.k12.or.us/contact/directory/
# 2114
# https://walpolewhs.ss5.sharpschool.com/staff_directory
# 2115
# https://www.warreneastoncharterhigh.org/apps/staff/
# 2116
# https://wasatchacademy.org/faculty-staff-directory
# 2117
# https://wasdhs.ss5.sharpschool.com/staff_directory
# 2118
# https://washington.crschools.us/
# 2119
# https://washington.fpschools.org/staff
# 2120
# https://washington.kckschools.org/about/faculty-staff
# 2121
# https://washington.sb.school/about_us/staff_directory
# 2122
# https://www.washingtoncountyschoolsga.org/
# 2123
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19647331939305
# 2124
# https://wattsschool.newdesignscharter.com/Teachers-and-Staff
# 2125
# https://waynesborohs.ss9.sharpschool.com/for_parents/Faculty%20Email%20Info
# 2126
# https://waysideschools.org/sths/
# 2127
# https://wbechs.beaufortschools.net/directory
# 2128
# https://wblahs.isd624.org/contact/directory
# 2129
# https://wccs.campbell.k12.va.us/home/faculty-directory
# 2130
# https://wccs.org/about-wccs/faculty-and-staff/
# 2131
# https://wchs.carteretcountyschools.org/staff_directory
# 2132
# https://wchs.epulaski.k12.in.us/
# 2133
# https://wchs.re3j.com/360800_2
# 2134
# https://www.washington.kyschools.us/students-families/staff-directory
# 2135
# https://wchs.washk12.org/faculty-directory/
# 2136
# https://www3.wayne.kyschools.us/staff
# 2137
# https://www.wcsdms.com/staff-directory-footer-link
# 2138
# https://wchs.whitecoschools.net/faculty-staff
# 2139
# https://www.whitley.kyschools.us/faculty-staff-directory
# 2140
# https://wchs.wilkescountyschools.org/apps/staff
# 2141
# http://wilkinsoncounty.schoolinsites.com/Default.asp?PN='Directory'&SubP=Directory&ShowNav=''&iSort='Department'
# 2142
# https://wchs.woodford.kyschools.us/en/staff
# 2143
# https://wcpsmd.com/schools/high-schools/washington-county-technical-high/staff-directory
# 2144
# https://wcpsmd.com/schools/high-schools/south-hagerstown-high/staff-directory
# 2145
# https://wcpsmd.com/schools/high-schools/williamsport-high/staff-directory
# 2146
# https://weatherfordchristian.com/business-directory/
# 2147
# https://wcss.org/about-us/leadership/
# 2148
# https://wcvwildcats.org/district/faculty-and-staff
# 2149
# https://wdhs.davidson.k12.nc.us/apps/staff/
# 2150
# https://wdhs.jcboe.org/apps/staff/
# 2151
# https://www.cobbk12.org/lassiter/page/11236/faculty-staff
# 2152
# https://www.cde.ca.gov/schooldirectory/details?cdscode=19644511931625
# 2153
# https://web.vigoschools.org/terre-haute-north/staff/
# 2154
# Deleting gateways for site 'https://www.google.com'.
# Deleted 10 endpoints with for site 'https://www.google.com'.
# ['f10hm4mk60',
#  'oegfybpobe',
#  'sdsw0ps477',
#  'wbq7iuu9w7',
#  'gcgc64xdfb',
#  'c2l1og4a78',
#  'x3qwwykohg',
#  'sgzchyo3w9',
#  'uk5qn2du22',
#  '3wwd8kt1c2']

# %%
len(lst)
# Out:
# 2154

# %%
directory_ser = pd.Series(lst)

# %%
directory_ser
# Out:
# 0                    https://www.pennmanor.net/directory/
# 1           https://highschool.plsd.k12.pa.us/apps/staff/
# 2         https://highschool.prc.k12.ms.us/administration
# 3        https://highschool.ptschools.org/staff_directory
# 4                 https://www.tylerisd.org/o/legacy/staff
#                               ...
# 2149          https://wdhs.davidson.k12.nc.us/apps/staff/
# 2150                   https://wdhs.jcboe.org/apps/staff/
# 2151    https://www.cobbk12.org/lassiter/page/11236/fa...
# 2152    https://www.cde.ca.gov/schooldirectory/details...
# 2153    https://web.vigoschools.org/terre-haute-north/...
# Length: 2154, dtype: object

# %%
copydf = df.copy()

# %%
sub_df = copydf.loc[2154:2154*2-1]

# %%
new_df = sub_df.reset_index()[['school_name','city','state','website']]

# %%
new_df['directory'] = pd.Series(lst)

# %%
new_df
# Out:
#                                  school_name           city           state  \
# 0                     penn manor high school   millersville    pennsylvania
# 1     purchase line juniorsenior high school      commodore    pennsylvania
# 2            pearl river central high school       carriere     mississippi
# 3                  port townsend high school  port townsend      washington
# 4                   tyler legacy high school     oro grande      california
# ...                                      ...            ...             ...
# 2149               west davidson high school      lexington  north carolina
# 2150         william l dickinson high school    jersey city      new jersey
# 2151                    lassiter high school        acworth         georgia
# 2152        columbus christopher high school         downey      california
# 2153      terre haute north vigo high school    terre haute         indiana
#
#                                                 website  \
# 0                     https://highschool.pennmanor.net/
# 1                    https://highschool.plsd.k12.pa.us/
# 2                     https://highschool.prc.k12.ms.us/
# 3                     https://highschool.ptschools.org/
# 4                 https://highschool.riversideprep.net/
# ...                                                 ...
# 2149                   https://wdhs.davidson.k12.nc.us/
# 2150                            https://wdhs.jcboe.org/
# 2151                  https://web.cobbk12.org/allatoona
# 2152                     https://web.dusd.net/columbus/
# 2153  https://web.vigoschools.org/terre-haute-north/...
#
#                                               directory
# 0                  https://www.pennmanor.net/directory/
# 1         https://highschool.plsd.k12.pa.us/apps/staff/
# 2       https://highschool.prc.k12.ms.us/administration
# 3      https://highschool.ptschools.org/staff_directory
# 4               https://www.tylerisd.org/o/legacy/staff
# ...                                                 ...
# 2149        https://wdhs.davidson.k12.nc.us/apps/staff/
# 2150                 https://wdhs.jcboe.org/apps/staff/
# 2151  https://www.cobbk12.org/lassiter/page/11236/fa...
# 2152  https://www.cde.ca.gov/schooldirectory/details...
# 2153  https://web.vigoschools.org/terre-haute-north/...
#
# [2154 rows x 5 columns]

# %%
new_df.to_csv('directory5.csv')
