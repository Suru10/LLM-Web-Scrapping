# %%
import pandas as pd
import googlesearch
import time
#high school, street address, city, state, website url

# %%
df = pd.read_csv('schools_to_be_farmed.csv')

# %%
# ********************************************************** TEST *************************************

# %%
df['query'] = df['school_name'] + ' in ' + df['city'] + ', ' + df['state'] + ' staff administration directory link'

# %%
df['query'].loc[0]
# Out:
# 'cabarrus early college of technology in concord, north carolina staff administration directory link'

# %%
query_list = df['query'].tolist()

# %%
len(query_list)/5
# Out:
# 2154.0

# %%
# ------------------------------------------------- WHOLE DATASET ------------------------------------------------------------------

# %%
query_list[0]
# Out:
# 'cabarrus early college of technology in concord, north carolina staff administration directory link'

# %%
import requests
from requests_ip_rotator import ApiGateway
import os
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import googlesearch
import re

keywords = query_list[2154*3:2154*4]

def parse(keyword, session):
    search = keyword
    url = 'https://www.google.com/search'
    
    headers = {
	'Accept' : '*/*',
	'Accept-Language': 'en-US,en;q=0.5',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82',
    }
    parameters = {'q': search}
    response = session.get(url, headers = headers, params = parameters)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        search = soup.find(id = 'search')
        first_link = search.find('a')
        print(first_link['href'])
        return first_link['href']
    else:
        print('Error')
        return 'Error'


AWS_ACCESS_KEY_ID = 'AKIAUYSFDI55SAGHWSXR'
AWS_SECRET_ACCESS_KEY = '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'

gateway = ApiGateway("https://www.google.com", access_key_id=AWS_ACCESS_KEY_ID,
                         access_key_secret=AWS_SECRET_ACCESS_KEY)
gateway.start()

session = requests.Session()
session.mount("https://www.google.com", gateway)
lst = []
count = 0
for keyword in keywords:
    lst.append(parse(keyword, session))
    count += 1
    print(count)
    
gateway.shutdown()
# Out:
# Starting API gateways in 10 regions.
# Using 10 endpoints with name 'https://www.google.com - IP Rotate API' (0 new).
# https://www.franklin.k12.al.us/domain/111
# 1
# https://www.franklincountyschools.org/domain/110
# 2
# https://www.franklinhigh.com/o/franklin-cusd-1/staff
# 3
# https://franklinhs.org/apps/staff/
# 4
# https://www.frankstonisd.net/staff
# 5
# https://www.fraser.k12.mi.us/Page/179
# 6
# https://www.frazee.k12.mn.us/contact-us
# 7
# https://www.frazierschooldistrict.org/frazierhighschool/highschooldirectory
# 8
# https://frcsminutemen.com/faculty/
# 9
# https://www.fredericaacademy.org/about-us/faculty-directory
# 10
# https://www.frederickcountyschoolsva.net/Page/1633
# 11
# https://www.fredonia.wnyric.org/staff
# 12
# https://www.fredoniaks.com/184022_2
# 13
# https://www.freedomareaschools.org/StaffDirectory.aspx
# 14
# https://www.freedomschools.k12.wi.us/district/staff-directory.cfm
# 15
# https://www.freemansd.org/Page/1935
# 16
# ...

# %%
len(lst)
# Out:
# 2154

# %%
directory_ser1 = pd.Series(lst)

# %%
directory_ser1
# Out:
# 0               https://www.franklin.k12.al.us/domain/111
# 1        https://www.franklincountyschools.org/domain/110
# 2       https://www.franklinhigh.com/o/franklin-cusd-1...
# 3                      https://franklinhs.org/apps/staff/
# 4                      https://www.frankstonisd.net/staff
#                               ...
# 2149              https://www.olemiss.k12.in.us/domain/45
# 2150                  https://www.ollsmcschools.org/staff
# 2151      https://www.olmcmd.org/about-us/faculty-staff-1
# 2152              https://www.olneyfriends.org/directory/
# 2153                    https://www.olneyisd.net/295503_2
# Length: 2154, dtype: object

# %%
copydf = df.copy()

# %%
copydf
# Out:
#                                              school_name            city  \
# 0                   cabarrus early college of technology         concord
# 1      perry career academy eula wilburn ponds perry ...       jonesboro
# 2                             nashville comm high school       nashville
# 3                                       edon high school            edon
# 4         explore knowledge academy j senior high school       las vegas
# ...                                                  ...             ...
# 10765                               sycamore high school      cincinnati
# 10766                         strom thurmond high school        johnston
# 10767          east stroudsburg senior high school north  dingmans ferry
# 10768        north star academy charter school of newark          newark
# 10769                    south gibson county high school          medina
#
#                 state                                       website  \
# ...

# %%
sub_df = copydf.loc[2154*3:2154*4-1]

# %%
sub_df
# Out:
#                                school_name         city       state  \
# 6462                   red bay high school      red bay     alabama
# 6463                franklin county school    eastpoint     florida
# 6464     franklin juniorsenior high school     franklin    illinois
# 6465  benjamin franklin senior high school  los angeles  california
# 6466                 frankston high school    frankston       texas
# ...                                    ...          ...         ...
# 8611              mississinewa high school     gas city     indiana
# 8612      st marys colgan catholic schools    pittsburg      kansas
# 8613       our lady of mount carmel school        essex    maryland
# 8614                  olney friends school  barnesville        ohio
# 8615                     olney high school        olney       texas
#
#                                                 website  \
# 6462           https://www.franklin.k12.al.us/Domain/15
# ...

# %%
new_df = sub_df.reset_index()[['school_name','city','state','website']]

# %%
new_df['directory'] = pd.Series(lst)

# %%
new_df
# Out:
#                                school_name         city       state  \
# 0                      red bay high school      red bay     alabama
# 1                   franklin county school    eastpoint     florida
# 2        franklin juniorsenior high school     franklin    illinois
# 3     benjamin franklin senior high school  los angeles  california
# 4                    frankston high school    frankston       texas
# ...                                    ...          ...         ...
# 2149              mississinewa high school     gas city     indiana
# 2150      st marys colgan catholic schools    pittsburg      kansas
# 2151       our lady of mount carmel school        essex    maryland
# 2152                  olney friends school  barnesville        ohio
# 2153                     olney high school        olney       texas
#
#                                                 website  \
# 0              https://www.franklin.k12.al.us/Domain/15
# ...

# %%
new_df.to_csv('directory2.csv')
